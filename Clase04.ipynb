# %% [markdown]
# **Funciones Matemáticas: Imagen y Preimagen**
#
# **La Función**
#
# Una función es una relación entre dos conjuntos, donde a cada elemento del primer conjunto (llamado dominio) le corresponde un único elemento del segundo conjunto (llamado codominio). La función se denota comúnmente como
# 𝑓
# :
# 𝐴
# →
# 𝐵
# f:A→B, donde
# 𝐴
# A es el dominio y
# 𝐵
# B es el codominio.
#
# ![image.png](data:image/png;base64,...)
#
# #**Notación:**
#
# 𝑓
# (
# 𝑥
# )
# =
# 𝑦
# f(x)=y, donde
# 𝑥
# ∈
# 𝐴
# x∈A y
# 𝑦
# ∈
# 𝐵
# y∈B.
#
# # **Dominio:**
#
# Conjunto de todos los posibles valores de entrada
#
# 𝑥
# x para la función.
#
# # **Codominio:**
#
# Conjunto de todos los posibles valores de salida
#
# 𝑦
# y.
#
# # **Gráfica:**
#
# Representación visual de una función, generalmente en un sistema de coordenadas.
#
# # **Imagen**
#
# La imagen de una función es el conjunto de todos los valores de salida
# 𝑦
#
# y que se obtienen al aplicar la función a cada uno de los elementos del dominio. Formalmente, si
# 𝑓
# :
# 𝐴
# →
# 𝐵
# f:A→B, entonces la imagen de
# 𝑓
# f se denota como
# 𝑓
# (
# 𝐴
# )
# f(A) o
# Im
# (
# 𝑓
# )
#
# Im(f) y se define como:
#
# Im
# (
# 𝑓
# )
# =
# {
# 𝑓
# (
# 𝑥
# )
# ∣
# 𝑥
# ∈
# 𝐴
# }
# Im(f)={f(x)∣x∈A}
#
# # **Preimagen**
#
# La preimagen, o contraimagen, de un subconjunto
# 𝐶
# C del codominio
# 𝐵
# B bajo una función
# 𝑓
# f es el conjunto de todos los elementos del dominio
# 𝐴
# A que son mapeados en los elementos de
# 𝐶
# C. Formalmente, si
# 𝑓
# :
# 𝐴
# →
# 𝐵
# f:A→B y
# 𝐶
# ⊆
# 𝐵
# C⊆B, entonces la preimagen de
# 𝐶
# C bajo
# 𝑓
# f se denota como
# 𝑓
# −
# 1
# (
# 𝐶
# )
# f
# −1
#
#  (C) y se define como:
#
# 𝑓
# −
# 1
# (
# 𝐶
# )
# =
# {
# 𝑥
# ∈
# 𝐴
# ∣
# 𝑓
# (
# 𝑥
# )
# ∈
# 𝐶
# }
# f
# −1
#  (C)={x∈A∣f(x)∈C}
#
# En el caso particular donde
# 𝐶
# C es un conjunto que contiene solo un elemento
# 𝑦
# y, es decir,
# 𝐶
# =
# {
# 𝑦
# }
# C={y}, entonces la preimagen de
# 𝑦
# y bajo
# 𝑓
# f se denota como
# 𝑓
# −
# 1
# (
# 𝑦
# )
# f
# −1
#  (y) y se define como:
#
# 𝑓
# −
# 1
# (
# 𝑦
# )
# =
# {
# 𝑥
# ∈
# 𝐴
# ∣
# 𝑓
# (
# 𝑥
# )
# =
# 𝑦
# }
# f
# −1
#  (y)={x∈A∣f(x)=y}
#
# **Ejemplos**
#
# # **Función lineal:**
#
# 𝑓
# (
# 𝑥
# )
# =
# 2
# 𝑥
# +
# 1
# f(x)=$2x+1$
#
# Dominio: Todos los números reales
# 𝑅
# R
# Codominio: Todos los números reales
# 𝑅
# R
# Imagen: Todos los números reales
# 𝑅
# R
#
# ![image.png](data:image/png;base64,...)
#
# # **Función cuadrática:**
#
# 𝑓
# (
# 𝑥
# )
# =
# 𝑥
# 2
# f(x)=$x$
# 2
#
# Dominio: Todos los números reales
# 𝑅
# R
# Codominio: Todos los números reales
# 𝑅
# R
# Imagen: Todos los números reales no negativos
# [
# 0
# ,
# ∞
# )
# [0,∞)
# Preimagen:
#
# Para
# 𝑓
# (
# 𝑥
# )
# =
# 𝑥
# 2
# f(x)=x
# 2
#  , la preimagen de 4 es
# 𝑓
# −
# 1
# (
# 4
# )
# =
# {
# −
# 2
# ,
# 2
# }
# f
# −1
#  (4)={−2,2} porque
# (
# −
# 2
# )
# 2
# =
# 4
# (−2)
# 2
#  =4 y
# 2
# 2
# =
# 4
# 2
# 2
#  =4.
#
#  ![image.png](data:image/png;base64,...)
